# %%
#importing the python libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import plotly.express as px

# %%
os.chdir("C:\\Users\\Dell\\Desktop\\DEVP")

# %%
#Reading the file
df=pd.read_csv('12-country_vaccinations.csv')

# %%
df.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  01-10-2021                 0.0                0.0
# 1  Albania      ALB  01-11-2021                 NaN                NaN
# 2  Albania      ALB  01-12-2021               128.0              128.0
# 3  Albania      ALB   1/13/2021               188.0              188.0
# 4  Albania      ALB   1/14/2021               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#checking the number of rows and columns in the data set
df.shape
# Out:
# (3946, 15)

# %%
#Checking for duplicate values
df.duplicated().sum() 
#There are no duplicate values in this dataset
# Out:
# 0

# %%
#Finding out the data type of each variable
df.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
df.describe().round()
#Shows the statistical summary of the numeric variables in the dataset
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count              2577.0             2176.0                   1431.0
# mean            1554471.0          1358450.0                 416946.0
# std             5216082.0          4276295.0                1592756.0
# min                   0.0                0.0                      1.0
# 25%               30252.0            28101.0                   9532.0
# 50%              189349.0           175047.0                  42553.0
# 75%              753669.0           670544.0                 216372.0
# max            64177474.0         44138118.0               19438495.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count                  2179.0              3800.0
# mean                  72224.0             55599.0
# std                  204186.0            175051.0
# min                  -50012.0                 1.0
# 25%                    1907.0              1130.0
# ...

# %%
df.columns
#Shows the column names in the dataset
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
# Looking for the unique values of Categorical Features in the dataset
print(df['country'].unique())
print(df['iso_code'].unique())
print(df['date'].unique())
print(df['vaccines'].unique())
print(df['source_name'].unique())
print(df['source_website'].unique())
# Out:
# ['Albania' 'Algeria' 'Andorra' 'Anguilla' 'Argentina' 'Australia'
#  'Austria' 'Azerbaijan' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Bermuda' 'Bolivia' 'Brazil' 'Bulgaria' 'Cambodia' 'Canada'
#  'Cayman Islands' 'Chile' 'China' 'Colombia' 'Costa Rica' 'Croatia'
#  'Cyprus' 'Czechia' 'Denmark' 'Dominican Republic' 'Ecuador' 'Egypt'
#  'England' 'Estonia' 'Faeroe Islands' 'Falkland Islands' 'Finland'
#  'France' 'Germany' 'Gibraltar' 'Greece' 'Greenland' 'Guernsey' 'Guyana'
#  'Hungary' 'Iceland' 'India' 'Indonesia' 'Iran' 'Ireland' 'Isle of Man'
#  'Israel' 'Italy' 'Japan' 'Jersey' 'Kuwait' 'Latvia' 'Lebanon'
#  'Liechtenstein' 'Lithuania' 'Luxembourg' 'Macao' 'Maldives' 'Malta'
#  'Mauritius' 'Mexico' 'Monaco' 'Morocco' 'Myanmar' 'Nepal' 'Netherlands'
#  'New Zealand' 'Northern Cyprus' 'Northern Ireland' 'Norway' 'Oman'
#  'Pakistan' 'Panama' 'Peru' 'Poland' 'Portugal' 'Qatar' 'Romania' 'Russia'
#  'Saint Helena' 'Saudi Arabia' 'Scotland' 'Serbia' 'Seychelles'
# ...

# %%
#Checking for Null values
df.isnull().sum()
# Out:
# country                                   0
# iso_code                                284
# date                                      0
# total_vaccinations                     1369
# people_vaccinated                      1770
# people_fully_vaccinated                2515
# daily_vaccinations_raw                 1767
# daily_vaccinations                      146
# total_vaccinations_per_hundred         1369
# people_vaccinated_per_hundred          1770
# people_fully_vaccinated_per_hundred    2515
# daily_vaccinations_per_million          146
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
#Finding out the total number of types of vaccines
df['vaccines'].value_counts()
# Out:
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1091
# Pfizer/BioNTech                                                                        895
# Oxford/AstraZeneca, Pfizer/BioNTech                                                    640
# Moderna, Pfizer/BioNTech                                                               332
# Sputnik V                                                                              214
# Oxford/AstraZeneca                                                                     179
# Sinovac                                                                                 81
# Pfizer/BioNTech, Sinovac                                                                70
# Oxford/AstraZeneca, Sinopharm/Beijing                                                   70
# Pfizer/BioNTech, Sinopharm/Beijing                                                      62
# ...

# %%
#Finding the total number of various types of sources used
df['source_name'].value_counts()
# Out:
# Ministry of Health                              1170
# Government of the United Kingdom                 355
# National Health Commission                       118
# Government of Israel                              66
# Centers for Disease Control and Prevention        65
#                                                 ...
# Government of Australia via covidlive.com.au       8
# Ministry of Public Health                          7
# Ministry of Health, Labour and Welfare             6
# Government of Greenland                            1
# Government of Saint Helena                         1
# Name: source_name, Length: 62, dtype: int64

# %%
#Finding the number of various sites used
df['source_website'].value_counts()
# Out:
# https://coronavirus.data.gov.uk/details/healthcare                                                                     355
# https://datadashboard.health.gov.il/COVID-19/general                                                                    66
# https://covid.cdc.gov/covid-data-tracker/#vaccinations                                                                  65
# https://twitter.com/MOH_Bahrain/status/1363959177241124871                                                              62
# https://www.gob.cl/yomevacuno/                                                                                          61
#                                                                                                                       ...
# https://www.facebook.com/moh.barbados/photos/a.768944336470972/3959608410737866/                                         7
# https://www.mhlw.go.jp/stf/seisakunitsuite/bunya/vaccine_sesshujisseki.html                                              6
# ...

# %%
df['country'].value_counts()
# Out:
# England             71
# United Kingdom      71
# Northern Ireland    71
# Scotland            71
# Wales               71
#                     ..
# Barbados             7
# Japan                6
# New Zealand          3
# Greenland            1
# Saint Helena         1
# Name: country, Length: 102, dtype: int64

# %%
df['iso_code'].value_counts()
# Out:
# GBR    71
# ISR    66
# USA    65
# BHR    62
# CRI    61
#        ..
# COL     7
# JPN     6
# NZL     3
# GRL     1
# SHN     1
# Name: iso_code, Length: 98, dtype: int64

# %%
#finding the number of dates on which people were vaccinated
df['date'].value_counts()
# Out:
# 02-09-2021    85
# 02-08-2021    84
# 2/13/2021     84
# 02-10-2021    84
# 2/14/2021     84
#               ..
# 12/18/2020     7
# 12/16/2020     7
# 12/15/2020     7
# 12/13/2020     5
# 12/14/2020     5
# Name: date, Length: 72, dtype: int64

# %%
df
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  01-10-2021                 0.0                0.0
# 1     Albania      ALB  01-11-2021                 NaN                NaN
# 2     Albania      ALB  01-12-2021               128.0              128.0
# 3     Albania      ALB   1/13/2021               188.0              188.0
# 4     Albania      ALB   1/14/2021               266.0              266.0
# ...       ...      ...         ...                 ...                ...
# 3941    Wales      NaN   2/17/2021            841975.0           822633.0
# 3942    Wales      NaN   2/18/2021            864498.0           839065.0
# 3943    Wales      NaN   2/19/2021            885906.0           853904.0
# 3944    Wales      NaN   2/20/2021            897856.0           860083.0
# 3945    Wales      NaN   2/21/2021            905000.0           862248.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(y='vaccines', data=df) 
#the number of different vaccines on a graph
# Out:
# <AxesSubplot:xlabel='count', ylabel='vaccines'>

# %%
color_map = ["lightgray" for _ in range(2)]
color_map[1] = "#2693d1"
sns.set_palette(sns.color_palette(color_map))
value_list = ['United States', 'England', 'India', 'China']
boolean_series = df.country.isin(value_list)
df['color'] = boolean_series
fig = plt.figure(figsize=(15, 15), facecolor='#f6f5f5')
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0, hspace=0)
ax0 = fig.add_subplot(gs[0, 0])
for s in ["right", "top"]:
    ax0.spines[s].set_visible(False)
ax0_sns = sns.scatterplot(ax=ax0, y=df['total_vaccinations_per_hundred'], x=df['total_vaccinations']/1000000, zorder=2, linewidth=0.3, edgecolor='black',  hue=df['color'], legend=False, size=1)
ax0_sns.set_xlabel("Vaccination (in million)",fontsize=5, weight='bold')
ax0_sns.set_ylabel("Vaccination per population (%)",fontsize=5, weight='bold')
ax0.grid(which='major', axis='x', zorder=0, color='#EEEEEE')
ax0.grid(which='major', axis='y', zorder=0, color='#EEEEEE')
ax0_sns.tick_params(labelsize=5)
plt.show()
#percentage of people vaccinated

# %%
plt.figure(figsize=(5,20))
plt.scatter('total_vaccinations','country',data=df)
#total vaccinations in different countries

# %%
sns.barplot(x=df['total_vaccinations'], y=df['vaccines'])
#different types of vaccines administered in millions
# Out:
# <AxesSubplot:xlabel='total_vaccinations', ylabel='vaccines'>

# %%
pd.crosstab(df.vaccines,df.country)
#Relationship between countries and vaccines
# Out:
# country                                             Albania  Algeria  Andorra  \
# vaccines
# Covaxin, Oxford/AstraZeneca                               0        0        0
# Johnson&Johnson                                           0        0        0
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech              0        0        0
# Moderna, Pfizer/BioNTech                                  0        0        0
# Oxford/AstraZeneca                                        0        0        0
# Oxford/AstraZeneca, Pfizer/BioNTech                       0        0        0
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/...        0        0        0
# Oxford/AstraZeneca, Sinopharm/Beijing                     0        0        0
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V          0        0        0
# Oxford/AstraZeneca, Sinovac                               0        0        0
# Oxford/AstraZeneca, Sputnik V                             0        0        0
# ...

# %%
pd.crosstab(df.iso_code,df.country)
#Relationship between iso code and countries
# Out:
# country   Albania  Algeria  Andorra  Anguilla  Argentina  Australia  Austria  \
# iso_code
# AIA             0        0        0        11          0          0        0
# ALB            41        0        0         0          0          0        0
# AND             0        0       26         0          0          0        0
# ARE             0        0        0         0          0          0        0
# ARG             0        0        0         0         56          0        0
# ...           ...      ...      ...       ...        ...        ...      ...
# SYC             0        0        0         0          0          0        0
# TCA             0        0        0         0          0          0        0
# TUR             0        0        0         0          0          0        0
# USA             0        0        0         0          0          0        0
# ZAF             0        0        0         0          0          0        0
#
# ...

# %%
plt.figure(figsize=(10,5))
df1 = df.sample(400)
sns.swarmplot(x='people_vaccinated_per_hundred',y='vaccines',data=df1)
#relationship between different vaccines and people vaccinated per hundred
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
